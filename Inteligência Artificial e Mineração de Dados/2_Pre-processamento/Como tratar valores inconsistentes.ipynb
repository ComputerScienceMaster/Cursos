# %%
import pandas as pd

data  = pd.read_csv('credito.csv')
data
# Out:
#           id  credit  sex  education  mariage  age
# 0          1   20000    2          2        1   24
# 1          2  120000    2          2        2   26
# 2          3   90000    2          2        2   34
# 3          4   50000    2          2        1   37
# 4          5   50000    1          2        1   57
# 5          6   50000    1          1        2   37
# 6          7  500000    1          1        2   29
# 7          8  100000    2          2        2   23
# 8          9  140000    2          3        1   28
# 9         10   20000    1          3        2   35
# 10        11  200000    2          3        2   34
# 11        12  260000    2          1        2   51
# 12        13  630000    2          2        2   41
# 13        14   70000    1          2        2   30
# 14        15  250000    1          1        2   29
# 15        16   50000    2          3        3   23
# 16        17   20000    1          1        2   24
# ...

# %%
# localizando clientes com idade negativa

data.loc[data['age'] < 0]
# Out:
#       id  credit  sex  education  mariage  age
# 63    64   50000    2          2        1   -4
# 160  161   30000    1          1        2  -50
# 303  304   20000    2          1        2  -20

# %%
# como tratar?
# excluir a coluna?

d = data.drop('age', 1 , inplace=False)
d
# Out:
#           id  credit  sex  education  mariage
# 0          1   20000    2          2        1
# 1          2  120000    2          2        2
# 2          3   90000    2          2        2
# 3          4   50000    2          2        1
# 4          5   50000    1          2        1
# 5          6   50000    1          1        2
# 6          7  500000    1          1        2
# 7          8  100000    2          2        2
# 8          9  140000    2          3        1
# 9         10   20000    1          3        2
# 10        11  200000    2          3        2
# 11        12  260000    2          1        2
# 12        13  630000    2          2        2
# 13        14   70000    1          2        2
# 14        15  250000    1          1        2
# 15        16   50000    2          3        3
# 16        17   20000    1          1        2
# 17        18  320000    1          1        1
# 18        19  360000    2          1        1
# ...

# %%
## pegando os indexes problematicos

indexesProblematicos = data[data.age < 0].index
# Out:
# Int64Index([63, 160, 303], dtype='int64')

# %%
# apagar somente o registro com problema

data.drop(indexesProblematicos, inplace=true)

# %%
# substituir as idades inválidas pelo valor da média

print(base['age'].mean())
print(base['age'][base.age > 0].mean())
data.loc[base.age < 0, 'age'] = 40.9
