# %%
import tweepy
import re
import pickle

from tweepy import OAuthHandler

# %%
# initializing the keys
consumer_key = 'czgXc6E6Qh5v0hlIFxbAz5vPj'
consumer_secret = '7gAeDmKp6MNyjxj8lcySuiuAz3jrBR0qebg0CYIMvA0STqCDJB'
access_token = '2729102759-RQf65P8m9VWzRr3nyxIaGFVaY3Dgasv2yTKJngT'
access_secret = 'lyZ6OHwnf2J5n7WPvaD8xjx5T8VWuLs3TMbUAxTGVIIIw'

# %%
auth = OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)

args = ['league of legends']

api = tweepy.API(auth,timeout=10)

# %%
list_tweets = []

query = args[0]
if len(args) == 1:
    for status in tweepy.Cursor(api.search, q=query + ' -filter:retweets', lang='en', result_type='recent').items(100):
        list_tweets.append(status.text)

# %%
# print (list_tweets)

# %%
with open('tfidfmodel.pickle', 'rb') as f:
    vectorizer = pickle.load(f)
    
with open('classifier.pickle', 'rb') as f:
    clf = pickle.load(f)
          
resultado = clf.predict(vectorizer.transform(['we are awesome']))
print (resultado)
# Out:
# [1]
# C:\Users\vini_\Anaconda3\lib\site-packages\sklearn\base.py:311: UserWarning: Trying to unpickle estimator CountVectorizer from version 0.19.2 when using version 0.19.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# C:\Users\vini_\Anaconda3\lib\site-packages\sklearn\base.py:311: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.19.2 when using version 0.19.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
# pré processamento

for tweet in list_tweets:
    tweet = re.sub(r"^https://t.co/[a-zA-Z0-9]*\s", " ", tweet)
    tweet = re.sub(r"\s+https://t.co/[a-zA-Z0-9]*\s", " ", tweet)
    tweet = re.sub(r"\s+https://t.co/[a-zA-Z0-9]*$", " ", tweet)
    tweet = tweet.lower()
    tweet = re.sub(r"that's", "that is", tweet)
    tweet = re.sub(r"what's", "what is", tweet)
    tweet = re.sub(r"where's", "where is", tweet)
    tweet = re.sub(r"it's", "it is", tweet)
    tweet = re.sub(r"who's", "who is", tweet)
    tweet = re.sub(r"i'm", "i am", tweet)
    tweet = re.sub(r"she's", "she is", tweet)
    tweet = re.sub(r"he's", "he is", tweet)
    tweet = re.sub(r"they're", "they are", tweet)
    tweet = re.sub(r"who're", "who are", tweet)
    tweet = re.sub(r"ain't", "am not", tweet)
    tweet = re.sub(r"wouldn't", "should not", tweet)
    tweet = re.sub(r"can't", "can not", tweet)
    tweet = re.sub(r"couldn't", "could not", tweet)
    tweet = re.sub(r"won't", "will not", tweet)
    tweet = re.sub(r"\W", " ", tweet)
    tweet = re.sub(r"\d", " ", tweet)
    tweet = re.sub(r"\s+[a-z]\s+", " ", tweet)
    tweet = re.sub(r"\s+[a-z]$", " ", tweet)
    tweet = re.sub(r"^[a-z]\s+", " ", tweet)
    tweet = re.sub(r"\s", " ", tweet)
    sent = clf.predict(vectorizer.transform([tweet]))
    print(tweet, ":", sent, "\n")
# Out:
#  added video to youtube playlist zedd  ignite   worlds        league of legends : [0]
#
#  added video to youtube playlist legends never die  ft  against the current    worlds        league of : [0]
#
#  added video to youtube playlist imagine dragons  warriors   worlds        league of legends : [0]
#
#  liked youtube video uzay serüveni  modu     league of legends gameplay : [0]
#
#   live   league of legends   mundial        fase de entrada   dia    via  youtube : [0]
#
#  liked youtube video  league of legends diamond iv yuhuhuhu facem si noi likeuri     : [0]
#
#  shaian     we re updating the emblems because they don fit the aesthetic of league of legends or the world of ru   : [1]
#
#   li league of legends makes me really pissed off lot  but the game itself isn the problem  it is assholes and   : [0]
#
# looking for some people who want to play league of legends with me  just for fun am terrible    but would like to play with group : [1]
#
#  liked youtube video rise  ft  the glitch mob  mako  and the word alive    worlds        league of legends : [0]
#
# new ryze skin spotlight         pre release   league of legends   thanks  riotgames  : [1]
#
# the permanent ban turned out to be not so permanent  here the story of  loltyler road to league of legends red   : [0]
#
# dia     league of legends : [0]
#
#  liked youtube video pulsefire ezreal        skin spotlight   pre release   league of legends : [0]
#
# intersting structure developments   : [1]
#
#  added video to youtube playlist league of legends   worlds        tristana   english stream   road to : [0]
#
# hey  check out riot games now streaming league of legends  : [0]
#
#  mennaeltouny game  league of legends : [0]
#
#  added video to youtube playlist imagine dragons  warriors   worlds        league of legends : [0]
#
#   live   league of legends   mundial        fase de entrada   dia    via  youtube : [0]
#
#  added video to youtube playlist zedd  ignite   worlds        league of legends : [0]
#
#  added video to youtube playlist legends never die  ft  against the current    worlds        league of : [0]
#
# ashena box fun will be starting soon will be playing league of legends with   : [1]
#
# league of legends using ninja in an ad   wtf : [1]
#
#  am now streaming on twitch  playing league of legends  : [0]
#
# this new league of legends ad keep seeing on twitch is the most obnoxious thing ever  not sure how some dude scre   : [1]
#
#          revenant smaller  vanilla  minecraft server with origins in league of legends esports league  all are   : [0]
#
#  kh ngboon hey can you create club in league of legends  : [0]
#
# acer named proud partner  amp  official monitor provider of esports      league of legends world championship   : [1]
#
#  mrtncrls possibly league of legends related haha : [0]
#
# ich mag das  youtube video  welcome aboard   odyssey animated trailer   league of legends : [0]
#
#  dirvitcom    para el league of legends : [0]
#
# we talked about the new lol park in south korea little bit on this weeks podcast   it is basically league of le   : [1]
#
#    head coach in lol    ggeaofficial    contract   previous coaching or analytical experience within the league of   : [1]
#
#  liked youtube video rise  ft  the glitch mob  mako  and the word alive    worlds        league of legends : [0]
#
# playing kawaii matches on league of legends girlstreamers  : [0]
#
# league of legends       series  get your teams ready  details can be found on our facebook events page    : [0]
#
#  added video to youtube playlist bungle in the jungle  league of legends animation  : [0]
#
# how hard is it to learn how to play league of legends  : [0]
#
#  am now streaming on twitch  playing league of legends  : [0]
#
# aaaaaaaand the  stream is  online  today starter is  league of legends but as always we go on with some   : [1]
#
# league of legends  via  youtube : [0]
#
# if you thought you missed out on our league of legends  utdim tournament  you re in luck  you now have week to si   : [0]
#
#  truegaming look like master yi from league of legends : [0]
#
# so this guy on league of legends arams starts in about how trash am cause pointed out he is playing blitzcrank   : [0]
#
#  annarobin   robinlawler   chrissyteigen how did you not go with league of legends   : [0]
#
# new look inspired by one of my other favourite games league of legends as lux  you been tagged   zylalaland   : [0]
#
# streaming some league of legends and then assembling the new gaming chair in    mins  tune in to make fun of how ba   : [1]
#
# youtube   the most broken video ever done  one auto   one kill graves one shot build      league of legends   profe   : [0]
#
#  ftplnewsgossip the first game of the legends league is about to start  manchester united vs liverpool  here are bo   : [0]
#
# campeonato mundial league of legends   detonation focusme vs cloud    play in groups       vía  youtube : [0]
#
# let start with everyone because it is free game called  league of legends   click here    leagueoflegends : [0]
#
# anyone here plays league of legends   : [0]
#
#  inktober    day   inktober     crossover league of legends   jour     tranquille day      tranquil  : [1]
#
#  want my gf to play league of legends or rainbow six since other sports games have toxic fanbase : [0]
#
# gostei de um vídeo  youtube never die  ft  against the current    worlds        league of legends : [0]
#
#  liked youtube video rise  ft  the glitch mob  mako  and the word alive    worlds        league of legends : [0]
#
#  thebigstomper  dtrecard   ben_porell  bigjeffyh  mat_perry minus    until league of legends : [0]
#
#  lassesays do you want to play league of legends instead : [0]
#
#  candrahastings   corissabaker started playing league of legends last night and we could totally pull off many  : [0]
#
# reaction to rise worlds        league of legends  leagueoflegends  lolworlds : [0]
#
#   happy october   playing some more league of legends today twitchstreamer   : [1]
#
#  going live in about    minutes folks  some league of legends on its way    : [0]
#
# accurate representation of me when m tilted in league of legends     : [0]
#
#  added video to youtube playlist how to play support in league of legends   support guide : [0]
#
#  added video to youtube playlist how to support   how to roam  ward and wave control   league of legends : [0]
#
#  make videos about league of legends and now tweet about league of legends : [0]
#
#  liked youtube video how to play support in league of legends   support guide : [0]
#
#  berkangulsen  csnaber league of legends : [0]
#
#   live   league of legends   mundial        fase de entrada via  youtube : [0]
#
# unbelievable quality of the champions league games from the guys at  darkmattertv_   absolute legends   best  : [1]
#
# how to watch the biggest  esport event of the year  league of legends world championship        : [1]
#
#  soraka  leagueoflegends  no text version for league of legends ask  : [0]
#
# este video  gt  el videoclip oficial de rise  ambition journey   rise music video parody   league of legends worlds   : [0]
#
# how to watch the biggest  esport event of the year  league of legends world championship        : [1]
#
#  fitzyfella  ewenmacintosh woahh chill out  just banter  don wanna upset couple of comedy legends  just making   : [0]
#
#  liked youtube video rise  league of legends    análisis musical : [0]
#
#  liked youtube video resumen dia    worlds      infinity complica sus opciones     league of legends : [0]
#
#  liked youtube video wie die challenger  twisted fate midlane       league of legends   deutsch   german  : [0]
#
#  liked youtube video resumen dia    worlds      infinity complica sus opciones     league of legends : [0]
#
# am apreciat un videoclip pe  youtube  league of legends opening    : [0]
#
#  liked youtube video rise  league of legends    análisis musical : [0]
#
#  added video to youtube playlist feeling stronger   league of legends cinematic montage : [0]
#
#  martinsfp  jonrussell ve spent like    on league of legends skins  admittedly when was much younger : [0]
#
# the most broken video ever done  one auto   one kill graves one shot build      league of legends  via : [0]
#
# perfect  autofill  ezreal    climb to master   league of legends  via  youtube : [1]
#
#  added video to youtube playlist against the sun   league of legends cinematic montage : [0]
#
# tranquil  yasuo  league of legends    inktober   inktober      : [0]
#
# today  stunning taliyah from league of legends by  rubeeamadare more   gaming  cosplay  : [1]
#
# bir  youtube videosu beğendim  darius montage      best darius plays   league of legends mid : [1]
#
# how to play vi jungle   league of legends vi gameplay   lol vi guide   vi season   build  amp  vi runes  via : [1]
#
#  liked youtube video get jinxed   jinx music video   league of legends : [0]
#
# league of legends world championship  : [1]
#
# hey  going live  starting with some league of legends and moving to pubg later  trying to combine lol with some wor   : [0]
#
#  triplecs     davidvonderhaar single popular game even stretched out over   years makes way more cash than the ye   : [1]
#
# league of legends     : [0]
#
# did you guess  edg_edward and  supmass would escape day   of the  worlds     play ins unscathed    well  probably  : [0]
#
#  liked youtube video rise  ft  the glitch mob  mako  and the word alive    worlds        league of legends : [0]
#
#  brttoficial rise  league of legends worlds : [0]
#
#  liked youtube video  salty  riots   neues   runensystem  league of legends   deutsch   german  : [0]
